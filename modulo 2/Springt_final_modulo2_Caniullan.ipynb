# %%
# VERSION 1

# ingresar cantidad de patentes
cantidad = int(input("ingrese la cantidad de pantente a clasificar: "))

# crear listas vacias para guardar patentes
list_amarillo = []
list_cafe = []
list_rojo = []
list_azul = []
list_verde = []

# iterar 
for i in range(cantidad):
  
  # ingresar patente y clasificar
  patente = input("ingrese los ultimos tres digitos de la patente: ")
  
  # clasificar patentes de color amarillo
  if patente[-1] == "1" or patente[-1] == "2":
    list_amarillo.append(patente)
  
  # clasificar patentes de color cafe
  elif patente[-1] == "3" or patente[-1] == "4":
    list_cafe.append(patente)
  
  # clasificar patentes de color rojo
  elif patente[-1] == "5" or patente[-1] == "6":
    list_rojo.append(patente)
 
 # clasificar patentes de color azul
  elif patente[-1] == "7" or patente[-1] == "8":
    list_azul.append(patente)
  
  # clasificar patentes de color verde
  elif patente[-1] == "9" or patente[-1] == "0":
    list_verde.append(patente)
  
  # sin clasificar 67
  else:
    print("la patente no se le asigna color por no cumplir las condiciones")

# imprimir las cantidades de patentes 
print("la cantidad de patentes amarillo es: ", len(list_amarillo))
print("la cantidad de patentes cafe es: ", len(list_cafe))
print("la cantidad de patentes rojo es: ", len(list_rojo))
print("la cantidad de patentes azul es: ", len(list_azul))
print("la cantidad de patentes verde es: ", len(list_verde))
# Out:
# ingrese la cantidad de pantente a clasificar: 10
# ingrese los ultimos tres digitos de la patente: 111
# ingrese los ultimos tres digitos de la patente: 222
# ingrese los ultimos tres digitos de la patente: 333
# ingrese los ultimos tres digitos de la patente: 444
# ingrese los ultimos tres digitos de la patente: 555
# ingrese los ultimos tres digitos de la patente: 666
# ingrese los ultimos tres digitos de la patente: 777
# ingrese los ultimos tres digitos de la patente: 888
# ingrese los ultimos tres digitos de la patente: 999
# ingrese los ultimos tres digitos de la patente: 000
# la cantidad de patentes amarillo es:  2
# la cantidad de patentes cafe es:  2
# la cantidad de patentes rojo es:  2
# la cantidad de patentes azul es:  2
# la cantidad de patentes verde es:  2

# %%
# VERSION 2

# ingresar cantidad de patentes
cantidad = int(input("ingrese la cantidad de pantente a clasificar: "))

# crear listas vacias para guardar patentes
list_amarillo = []
list_cafe = []
list_rojo = []
list_azul = []
list_verde = []

# iterar 
for i in range(cantidad):
  
  # ingresar patente y clasificar
  patente = input("ingrese los ultimos tres digitos de la patente: ")
  
  # clasificar patentes de color amarillo
  if patente[-1] == "1" or patente[-1] == "2":
    print("la patente es amarilla")
    list_amarillo.append(patente)
    print("patente agregada a la lista",list_amarillo)
  
  # clasificar patentes de color cafe
  elif patente[-1] == "3" or patente[-1] == "4":
    print("la patente es cafe")
    list_cafe.append(patente)
    print(list_cafe)
  
  # clasificar patentes de color rojo
  elif patente[-1] == "5" or patente[-1] == "6":
    print("la patente es rojo")
    list_rojo.append(patente)
    print(list_rojo)
 
 # clasificar patentes de color azul
  elif patente[-1] == "7" or patente[-1] == "8":
    print("la patente es azul")
    list_azul.append(patente)
    print(list_azul)
  
  # clasificar patentes de color verde
  elif patente[-1] == "9" or patente[-1] == "0":
    print("la patente es verde")
    list_verde.append(patente)
    print(list_verde)
  
  # sin clasificar 67
  else:
    print("la patente no se le asigna color por no cumplir las condiciones")

# imprimir las cantidades de patentes 
print("la cantidad de patentes amarillo es: ", len(list_amarillo))
print("la cantidad de patentes cafe es: ", len(list_cafe))
print("la cantidad de patentes rojo es: ", len(list_rojo))
print("la cantidad de patentes azul es: ", len(list_azul))
print("la cantidad de patentes verde es: ", len(list_verde))
# Out:
# ingrese la cantidad de pantente a clasificar: 10
# ingrese los ultimos tres digitos de la patente: 123
# la patente es cafe
# ['123']
# ingrese los ultimos tres digitos de la patente: 234
# la patente es cafe
# ['123', '234']
# ingrese los ultimos tres digitos de la patente: 345
# la patente es rojo
# ['345']
# ingrese los ultimos tres digitos de la patente: 456
# la patente es rojo
# ['345', '456']
# ingrese los ultimos tres digitos de la patente: 567
# la patente es azul
# ['567']
# ingrese los ultimos tres digitos de la patente: 678
# la patente es azul
# ['567', '678']
# ingrese los ultimos tres digitos de la patente: 789
# la patente es verde
# ['789']
# ingrese los ultimos tres digitos de la patente: 890
# la patente es verde
# ['789', '890']
# ingrese los ultimos tres digitos de la patente: 901
# la patente es amarilla
# patente agregada a la lista ['901']
# ingrese los ultimos tres digitos de la patente: 058
# la patente es azul
# ['567', '678', '058']
# ...
